# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import gridspec
from scipy import stats
import os
from Elrond.P2_PostProcess.VirtualReality.plotting import get_vmin_vmax, min_max_normalize, plot_firing_rate_maps_short

# %%
spike_data = pd.read_pickle("/mnt/datastore/Chris/Cohort12/derivatives/M29/D25/vr/kilosort4/spikes.pkl")

# %%
example_data = spike_data[spike_data["cluster_id"] == 374]

# %%
plot_firing_rate_maps_short(example_data)
